# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
color=sns.color_palette()
from pylab import mpl
#plotly是开挂的作图神器,可以供js, python, R, DB等使用
import plotly.offline as py
import plotly.graph_objs as go
import plotly.offline as offline
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']

train = pd.read_csv( './data/base_data/public.train.csv')
test = pd.read_csv( './data/base_data/public.test.csv')
pd.set_option('display.max_column',100)
print(train.head())
# Out:
#    ID     板温  现场温度  光照强度   转换效率   转换效率A  转换效率B   转换效率C  电压A  电压B  电压C   电流A  \
# 0  10 -19.14 -17.4    34  80.55  106.32  16.98  118.36  729  709  725  1.34
# 1  11 -18.73 -17.3    30  99.90  139.00  21.20  139.51  728  717  726  1.55
# 2  12 -17.54 -17.0    41  82.48  114.86  14.91  117.66  731  722  720  1.75
# 3  14 -15.43 -16.6    53  73.98  101.72  15.55  104.67  730  727  726  2.02
# 4  15 -14.60 -16.3    65  64.62   86.86  13.09   93.92  727  729  728  2.13
#
#     电流B   电流C      功率A     功率B      功率C     平均功率   风速   风向       发电量
# 0  0.22  1.50   976.86  155.98  1087.50   740.11  0.6  272  1.437752
# 1  0.24  1.56  1128.40  172.08  1132.56   811.01  0.8  275  1.692575
# 2  0.23  1.82  1279.25  166.06  1310.40   918.57  1.1  283  1.975787
# 3  0.31  2.09  1474.60  225.37  1517.34  1072.44  0.9  280  2.370656
# 4  0.32  2.30  1548.51  233.28  1674.40  1152.06  1.1  280  2.532091

# %%
train.describe()
# Out:
#                  ID           板温         现场温度         光照强度          转换效率  \
# count   9000.000000  9000.000000  9000.000000  9000.000000   9000.000000
# mean    9062.866444     6.703914    -0.629456   339.890222     64.077781
# std     5114.232566    11.742366    67.430126   220.132765    807.424850
# min       10.000000   -24.790000 -6321.700000     0.000000      0.000000
# 25%     4682.750000    -1.870000    -7.600000   153.000000     20.510000
# 50%     9083.500000     5.640000    -2.400000   314.000000     25.230000
# 75%    13470.000000    15.620000     8.100000   526.000000     37.190000
# max    17876.000000    36.490000    78.700000   941.000000  60856.240000
#
#               转换效率A          转换效率B         转换效率C           电压A           电压B  \
# count   9000.000000    9000.000000   9000.000000   9000.000000   9000.000000
# mean      52.906926      84.416487     54.909988    717.852444    722.317556
# std      606.060373    2191.630414    705.950654   1931.338424   2048.559736
# ...

# %% [markdown]
# # 1.展示所有属性的分布情况

# %%
test.describe()
# Out:
#                  ID           板温         现场温度         光照强度          转换效率  \
# count   8409.000000  8409.000000  8409.000000  8409.000000   8409.000000
# mean    9134.017362     6.743565    -0.532370   340.494232     67.180684
# std     5135.024213    11.733794    70.730474   220.139546    927.594047
# min        1.000000   -23.890000 -6414.200000     0.000000      0.000000
# 25%     4732.000000    -1.790000    -7.500000   155.000000     20.400000
# 50%     9262.000000     5.560000    -2.300000   312.000000     25.060000
# 75%    13576.000000    15.470000     8.300000   529.000000     36.960000
# max    17875.000000    36.800000    54.500000   934.000000  61448.540000
#
#                转换效率A         转换效率B         转换效率C           电压A           电压B  \
# count    8409.000000   8409.000000   8409.000000   8409.000000   8409.000000
# mean       61.592292     71.052603     68.897216    692.506243    759.009989
# std      2022.687363   1311.881379   1350.963592   1413.713947   2545.796157
# ...

# %%
train['板温'].plot(title='col 1',kind='line',ylim=[-30,30],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['现场温度'].plot(title='col 2',kind='line',ylim=[-30,30],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['光照强度'].plot(title='col 3',kind='line',ylim=[0,800],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['光照强度'].plot(title='col 4',kind='line',ylim=[0,800],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['转换效率'].plot(title='col 5',kind='line',ylim=[0,1500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['转换效率A'].plot(title='col 6',kind='line',ylim=[0,1500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['转换效率B'].plot(title='col 7',kind='line',ylim=[0,1500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['转换效率C'].plot(title='col 8',kind='line',ylim=[0,1500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['电压A'].plot(title='col 9',kind='line',ylim=[0,1500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['电压B'].plot(title='col 10',kind='line',ylim=[0,1500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['电压C'].plot(title='col 11',kind='line',ylim=[0,2500],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['电流A'].plot(title='col 12',kind='line',ylim=[0,10],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['电流B'].plot(title='col 13',kind='line',ylim=[0,10],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['电流C'].plot(title='col 14',kind='line',ylim=[0,10],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['功率A'].plot(title='col 15',kind='line',ylim=[0,6000],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['功率B'].plot(title='col 16',kind='line',ylim=[0,7000],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['功率C'].plot(title='col 17',kind='line',ylim=[0,7000],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['平均功率'].plot(title='col 18',kind='line',ylim=[0,6000],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['风速'].plot(title='col 19',kind='line',ylim=[0,10],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['风向'].plot(title='col 20',kind='line',ylim=[0,367],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans

# %%
train['发电量'][0:1000].plot(title='col 21',kind='line',ylim=[0,15],figsize=(20, 6))
# Out:
# d:\python35\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning:
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
